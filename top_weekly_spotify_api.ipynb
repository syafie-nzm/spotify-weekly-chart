# %% [markdown]
# <a href="https://colab.research.google.com/github/syafie-nzm/spotify-weekly-chart/blob/main/top_weekly_spotify_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spotipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 5.8 MB/s eta 0:00:00
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = '2bb47ef8c4c2402cbecb2cb5c48ed809'
client_secret = 'a0f6b0a1dbdc41918ebee0859fb39836'

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = 'https://open.spotify.com/playlist/37i9dQZEVXbKcS4rq3mEhp?si=1e7aa409682a4167'
playlist_URI = playlist_link.split('/')[-1].split('?')[0]
#track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
sp.playlist_tracks(playlist_URI)["items"]

# %%
track_ls = []
position = 1
for track in sp.playlist_tracks(playlist_URI)["items"]:
    #Track URI
    track_uri = track["track"]["uri"]

    #Track name
    track_name = track["track"]["name"]

    #Main Artist
    artist_uri = track["track"]["artists"][0]["uri"]
    artist_info = sp.artist(artist_uri)

    #Name, popularity, genre
    artist_name = track["track"]["artists"][0]["name"]
    artist_pop = artist_info["popularity"]
    artist_genres = artist_info["genres"]

    #Album
    album = track["track"]["album"]["name"]

    #Popularity of the track
    track_pop = track["track"]["popularity"]

    #Track audio features
    audio_features = sp.audio_features(track_uri)
    danceablity = audio_features[0]['danceability']
    energy = audio_features[0]['energy']
    key = audio_features[0]['key']
    loudness = audio_features[0]['loudness']
    mode = audio_features[0]['mode']
    speechiness = audio_features[0]['speechiness']
    acousticness = audio_features[0]['acousticness']
    instrumentalness = audio_features[0]['instrumentalness']
    liveness = audio_features[0]['liveness']
    valence = audio_features[0]['valence']
    tempo = audio_features[0]['tempo']

    track_ls.append({'Position' : position,
                    'Track URI': track_uri,
                    'Artist': artist_name,
                    'Track Name': track_name,
                    'Album Name': album,
                    'Artist Popularity': artist_pop,
                    'Artist Genre': artist_genres,
                    'Track Popularity': track_pop,
                    'Danceability': danceablity,
                    'Energy': energy,
                    'key': key,
                    'loudness': loudness,
                    'mode': mode,
                    'speechiness': speechiness,
                    'acousticness': acousticness,
                    'instrumentalness': instrumentalness,
                    'liveness': liveness,
                    'valence': valence,
                    'tempo': tempo})
    position += 1

# %%
import csv

csv_path = '/content/drive/MyDrive/raw_spotify_2.csv'

with open(csv_path, 'w', newline='') as csvfile:
    fieldnames = track_ls[0].keys()
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for row in track_ls:
        writer.writerow(row)

print(f'Data written to {csv_path}')
# Out:
# Data written to /content/drive/MyDrive/raw_spotify_2.csv

# %%
import pandas as pd

df = pd.read_csv(csv_path)
df
# Out:
#     Position                             Track URI             Artist  \
# 0          1  spotify:track:7x9aauaA9cu6tyfpHnqDLo          Jung Kook
# 1          2  spotify:track:6XsFgTG4dY768oIB4Dmeu0     Ghea Indrawari
# 2          3  spotify:track:3rUGC1vUpkDG9CZFHMur1t         Tate McRae
# 3          4  spotify:track:01qFKNWq73UfEslI0GvumE          Jung Kook
# 4          5  spotify:track:26cvTWJq2E1QqN4jyH2OTU       Anggi Marito
# 5          6  spotify:track:3vkCueOmm7xQDoJ17W1Pm3             Mitski
# 6          7  spotify:track:6gcuJpHu0Ey30D5WR76y98             JENNIE
# 7          8  spotify:track:1BxfuPKGuaTgP7aM0Bbdwr       Taylor Swift
# 8          9  spotify:track:1Qrg8KqiBpW07V7PNxwwwL                SZA
# 9         10  spotify:track:5sdQOyqq2IDhvmx2lHOpwd           NewJeans
# 10        11  spotify:track:56y1jOTK0XSvJzVv9vHQBK           Doja Cat
# 11        12  spotify:track:5GqeQ8Xozl7ymUVV7RXjNg              Masdo
# ...

# %%
print(df.dtypes)
# Out:
# Position               int64
# Track URI             object
# Artist                object
# Track Name            object
# Album Name            object
# Artist Popularity      int64
# Artist Genre          object
# Track Popularity       int64
# Danceability         float64
# Energy               float64
# key                    int64
# loudness             float64
# mode                   int64
# speechiness          float64
# acousticness         float64
# instrumentalness     float64
# liveness             float64
# valence              float64
# tempo                float64
# dtype: object

# %%
save_path = '/content/drive/MyDrive/cleaned_spotify_2.csv'
df.to_csv(save_path, index=False)
